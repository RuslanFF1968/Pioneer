# %% [markdown]
# <a href="https://colab.research.google.com/github/RuslanFF1968/Pioneer/blob/main/Geocode_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
from geopandas.tools import geocode

# %%
loc = 'Orenburg'

# %%
location = geocode(loc, provider="nominatim" , user_agent = 'my_request')
location
# Out:
#                     geometry  \
# 0  POINT (55.09785 51.76712)
#
#                                              address
# 0  Оренбург, городской округ Оренбург, Оренбургск...

# %%
point = location.geometry.iloc[0]
print('Name: '+ loc )
print('complete address: '+ location.address.iloc[0])
print('longitude: {} '.format(point.x))
print('latitude: {} '.format(point.y))
# Out:
# Name: Orenburg
# complete address: Оренбург, городской округ Оренбург, Оренбургская область, Приволжский федеральный округ, 460000, Россия
# longitude: 55.0978517
# latitude: 51.7671248

# %%
import folium

# %%
cities = ['Orenburg', 'Orsk','Buzuluk']

# %%
df = pd.DataFrame({'cities' : cities})
df
# Out:
#      cities
# 0  Orenburg
# 1      Orsk
# 2   Buzuluk

# %%
def custom_geocoder(address):
  dataframe = geocode(address , provider="nominatim" , user_agent = 'my_request')
  point = dataframe.geometry.iloc[0]
  return pd.Series({'Latitude': point.y, 'Longitude': point.x})

# %%
df[['latitude' , 'longitude']]= df.cities.apply( lambda x: custom_geocoder(x))
df
# Out:
#      cities   latitude  longitude
# 0  Orenburg  51.767125  55.097852
# 1      Orsk  51.230502  58.473802
# 2   Buzuluk  52.788502  52.253899
