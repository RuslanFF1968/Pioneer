# %% [markdown]
# <a href="https://colab.research.google.com/github/RuslanFF1968/Pioneer/blob/main/Data_retrieval_from_the_source_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SQL for data upload from the relational DB in Pandas

# %%
# Hostname: hh-pgsql-public.ebi.ac.uk
# Port: 5432
# Database: pfmegrnargs
# User: reader
# Password: NWDMCE5xdipIjRrp

# %%
from sqlalchemy import text, create_engine
import pandas as pd
engine = create_engine('postgresql://reader:NWDMCE5xdipIjRrp@hh-pgsql-public.ebi.ac.uk:5432/pfmegrnargs')
with engine.begin() as conn:
    query = text('SELECT * FROM rnc_rna_precomputed precomputed limit 10;')
    data_frame = pd.read_sql_query(query, conn)

# %%
data_frame.head()
# Out:
#                       id    taxid   description            upi rna_type  \
# 0  URS0001E5E3B1_1649191  1649191  Generic rRNA  URS0001E5E3B1     rRNA
# 1   URS000069EB31_768304   768304  Generic tRNA  URS000069EB31     tRNA
# 2   URS000069EB31_768305   768305  Generic tRNA  URS000069EB31     tRNA
# 3   URS000069EB31_768306   768306  Generic tRNA  URS000069EB31     tRNA
# 4   URS000069EB31_768307   768307  Generic tRNA  URS000069EB31     tRNA
#
#   update_date  has_coordinates databases  is_active  last_release  \
# 0  2020-08-20            False                False           468
# 1  2018-03-19            False                False           127
# 2  2018-03-19            False                False           127
# 3  2018-03-19            False                False           127
# 4  2018-03-19            False                False           127
#
#   short_description so_rna_type  is_locus_representative assigned_so_rna_type
# ...

# %% [markdown]
# ## REST API with requests lib

# %% [markdown]
#       /posts	100 posts
#       /comments	500 comments
#       /albums	100 albums
#       /photos	5000 photos
#       /todos	200 todos
#       /users	10 users

# %%
import requests
import json


res = requests.get("https://jsonplaceholder.typicode.com/posts/1")
json.loads(res.content)
# Out:
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
data = {u'body': u'Hi There this is my first post',
 u'id': 501,
 u'title': u'first post',
 u'userId': 1}

res = requests.post("https://jsonplaceholder.typicode.com/posts",data=data)
res.text
# Out:
# '{\n  "body": "Hi There this is my first post",\n  "id": 101,\n  "title": "first post",\n  "userId": "1"\n}'
